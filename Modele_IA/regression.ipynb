# %% [markdown]
# ### Import librairies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import metrics
from matplotlib import rcParams
rcParams['figure.figsize'] = 11.7,8.27

# %% [markdown]
# ### Import dataset

# %%
df = pd.read_json(r"data_harvest.json", lines=True)

df.head()
# Out:
#                                                  url  status  \
# 0  https://www.paruvendu.fr/a/voiture-occasion/ci...     200
# 1  https://www.paruvendu.fr/a/voiture-occasion/mi...     200
# 2  https://www.paruvendu.fr/a/voiture-occasion/mi...     200
# 3  https://www.paruvendu.fr/a/voiture-occasion/da...     200
# 4  https://www.paruvendu.fr/a/voiture-occasion/da...     200
#
#                    location                                   version  \
# 0   le thuit-signol (27370)          version ds3 puretech 82 bvm chic
# 1              68000 colmar   version 1.5 d 116 cooper pack chili bva
# 2           chorges (05230)            version mini 1.6i - 120 cooper
# 3            liévin (62800)  version duster blue dci 115 4x2 prestige
# 4  clermont-ferrand (63100)    version duster dci 110 4x4 black touch
#
#            price                                               year  \
# 0  prix 11 000 €  année novembre 2015 le comparateur d'assurance...
# 1  prix 18 490 €  année octobre 2017 le comparateur d'assurance ...
# 2   prix 8 700 €  année juin 2009 le comparateur d'assurance pou...
# 3  prix 19 800 €  année janvier 2022 le comparateur d'assurance ...
# 4  prix 16 000 €  année février 2017 le comparateur d'assurance ...
#
#                  mileage        fuel_type                   emission  \
# 0  kilométrage 46 000 km  energie essence  emissions de co2 104 g/km
# 1  kilométrage 52 800 km   energie diesel                        N/A
# 2  kilométrage 83 700 km  energie essence  emissions de co2 129 g/km
# 3   kilométrage 2 000 km   energie diesel                        N/A
# 4  kilométrage 67 000 km   energie diesel  emissions de co2 123 g/km
#
#                                fuel_usage              transmission  \
# 0  consommation mixte 4.5 litres / 100 km     transmission manuelle
# 1                                     N/A  transmission automatique
# 2  consommation mixte 5.4 litres / 100 km     transmission manuelle
# 3                                     N/A     transmission manuelle
# 4  consommation mixte 4.7 litres / 100 km     transmission manuelle
#
#                      door_nb         technical_power seat_nb actual_power  \
# 0  nombre de places 5 places  puissance fiscale 4 cv     N/A           82
# 1  nombre de places 5 places  puissance fiscale 6 cv     N/A          116
# 2  nombre de places 4 places  puissance fiscale 6 cv     N/A          120
# 3  nombre de places 5 places  puissance fiscale 6 cv     N/A          115
# 4  nombre de places 5 places  puissance fiscale 6 cv     N/A          110
#
#   body_colour body_type warranty control
# 0         N/A   berline      N/A     N/A
# 1  gris foncé       N/A      N/A     N/A
# 2  gris foncé   berline      N/A     N/A
# 3       blanc       4x4      N/A     N/A
# 4         N/A       4x4      N/A     N/A

# %%
df.describe()
df_clean=df.drop(['status','seat_nb','warranty','control'],axis=1)
df_clean.head()
df['body_colour'].value_counts()
# Out:
# blanc                 1393
# noir                  1235
# N/A                    730
# gris clair             671
# gris                   452
#                       ...
# m misanoblau             1
# galvanic gold            1
# peinture bleu iron       1
# beige metal              1
# omaha orange             1
# Name: body_colour, Length: 718, dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8269 entries, 0 to 8268
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              8269 non-null   object
#  1   location         8269 non-null   object
#  2   version          8269 non-null   object
#  3   price            8269 non-null   object
#  4   year             8269 non-null   object
#  5   mileage          8269 non-null   object
#  6   fuel_type        8269 non-null   object
#  7   emission         8269 non-null   object
#  8   fuel_usage       8269 non-null   object
#  9   transmission     8269 non-null   object
#  10  door_nb          8269 non-null   object
#  11  technical_power  8269 non-null   object
#  12  actual_power     8269 non-null   object
#  13  body_colour      8269 non-null   object
#  14  body_type        8269 non-null   object
# dtypes: object(15)
# memory usage: 969.1+ KB

# %%
df_clean["transmission"].astype('category')

df_clean["body_colour"].astype('category')

df_clean["body_type"].astype('category')
# Out:
# 0       berline
# 1           N/A
# 2       berline
# 3           4x4
# 4           4x4
#          ...
# 8264    berline
# 8265    berline
# 8266    berline
# 8267    berline
# 8268    berline
# Name: body_type, Length: 8269, dtype: category
# Categories (9, object): ['4x4', 'N/A', 'berline', 'break', ..., 'coupé', 'monospace', 'pick-up', 'véhicule']

# %%
for i in range(0, len(df_clean)): 
    df_clean.iloc[i].price = df_clean.iloc[i].price[4:-1] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].mileage = df_clean.iloc[i].mileage[11:-2] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].fuel_type = df_clean.iloc[i].fuel_type[8:] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].emission = df_clean.iloc[i].emission[16:-5] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].door_nb = df_clean.iloc[i].door_nb[16:-6] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].technical_power = df_clean.iloc[i].technical_power[17:-2] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].transmission = df_clean.iloc[i].transmission[12:] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].fuel_usage = df_clean.iloc[i].fuel_usage[19:-16] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].url = df_clean.iloc[i].url[44:-22] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].version = df_clean.iloc[i].version[8:] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].year = df_clean.iloc[i].year[6:] 

df_clean.head()
# Out:
#             url                  location                           version  \
# 0   citroen/ds3   le thuit-signol (27370)          ds3 puretech 82 bvm chic
# 1   mini/cooper              68000 colmar   1.5 d 116 cooper pack chili bva
# 2   mini/cooper           chorges (05230)            mini 1.6i - 120 cooper
# 3  dacia/duster            liévin (62800)  duster blue dci 115 4x2 prestige
# 4  dacia/duster  clermont-ferrand (63100)    duster dci 110 4x4 black touch
#
#       price                                               year   mileage  \
# 0   11 000   novembre 2015 le comparateur d'assurance pour ...   46 000
# 1   18 490   octobre 2017 le comparateur d'assurance pour c...   52 800
# 2    8 700   juin 2009 le comparateur d'assurance pour cett...   83 700
# 3   19 800   janvier 2022 le comparateur d'assurance pour c...    2 000
# 4   16 000   février 2017 le comparateur d'assurance pour c...   67 000
#
#   fuel_type emission fuel_usage  transmission door_nb technical_power  \
# 0   essence      104        4.5      manuelle      5               4
# 1    diesel                       automatique      5               6
# 2   essence      129        5.4      manuelle      4               6
# 3    diesel                          manuelle      5               6
# 4    diesel      123        4.7      manuelle      5               6
#
#   actual_power body_colour body_type
# 0           82         N/A   berline
# 1          116  gris foncé       N/A
# 2          120  gris foncé   berline
# 3          115       blanc       4x4
# 4          110         N/A       4x4

# %%
df_marque=df_clean['url'].str.split('/',expand=True)
df_clean['marque']=df_marque[0]
df_clean['modele']=df_marque[1]
df_clean.drop(columns =["url"], inplace = True)
df_clean.head()
# Out:
#                    location                           version     price  \
# 0   le thuit-signol (27370)          ds3 puretech 82 bvm chic   11 000
# 1              68000 colmar   1.5 d 116 cooper pack chili bva   18 490
# 2           chorges (05230)            mini 1.6i - 120 cooper    8 700
# 3            liévin (62800)  duster blue dci 115 4x2 prestige   19 800
# 4  clermont-ferrand (63100)    duster dci 110 4x4 black touch   16 000
#
#                                                 year   mileage fuel_type  \
# 0  novembre 2015 le comparateur d'assurance pour ...   46 000    essence
# 1  octobre 2017 le comparateur d'assurance pour c...   52 800     diesel
# 2  juin 2009 le comparateur d'assurance pour cett...   83 700    essence
# 3  janvier 2022 le comparateur d'assurance pour c...    2 000     diesel
# 4  février 2017 le comparateur d'assurance pour c...   67 000     diesel
#
#   emission fuel_usage  transmission door_nb technical_power actual_power  \
# 0      104        4.5      manuelle      5               4            82
# 1                       automatique      5               6           116
# 2      129        5.4      manuelle      4               6           120
# 3                          manuelle      5               6           115
# 4      123        4.7      manuelle      5               6           110
#
#   body_colour body_type   marque  modele
# 0         N/A   berline  citroen     ds3
# 1  gris foncé       N/A     mini  cooper
# 2  gris foncé   berline     mini  cooper
# 3       blanc       4x4    dacia  duster
# 4         N/A       4x4    dacia  duster

# %%
df_year=df_clean['year'].str.split(' le',expand=True)
df_clean['date_fabrication']=df_year[0]
df_clean.drop(columns =["year"], inplace = True)
df_clean.head()
# Out:
#                    location                           version     price  \
# 0   le thuit-signol (27370)          ds3 puretech 82 bvm chic   11 000
# 1              68000 colmar   1.5 d 116 cooper pack chili bva   18 490
# 2           chorges (05230)            mini 1.6i - 120 cooper    8 700
# 3            liévin (62800)  duster blue dci 115 4x2 prestige   19 800
# 4  clermont-ferrand (63100)    duster dci 110 4x4 black touch   16 000
#
#     mileage fuel_type emission fuel_usage  transmission door_nb  \
# 0   46 000    essence      104        4.5      manuelle      5
# 1   52 800     diesel                       automatique      5
# 2   83 700    essence      129        5.4      manuelle      4
# 3    2 000     diesel                          manuelle      5
# 4   67 000     diesel      123        4.7      manuelle      5
#
#   technical_power actual_power body_colour body_type   marque  modele  \
# 0              4            82         N/A   berline  citroen     ds3
# 1              6           116  gris foncé       N/A     mini  cooper
# 2              6           120  gris foncé   berline     mini  cooper
# 3              6           115       blanc       4x4    dacia  duster
# 4              6           110         N/A       4x4    dacia  duster
#
#   date_fabrication
# 0    novembre 2015
# 1     octobre 2017
# 2        juin 2009
# 3     janvier 2022
# 4     février 2017

# %%
df_clean['location'] = df_clean['location'].str.replace(r'\D', '')
df_clean.head()
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_12988\1448279508.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_clean['location'] = df_clean['location'].str.replace(r'\D', '')
#   location                           version     price   mileage fuel_type  \
# 0    27370          ds3 puretech 82 bvm chic   11 000    46 000    essence
# 1    68000   1.5 d 116 cooper pack chili bva   18 490    52 800     diesel
# 2    05230            mini 1.6i - 120 cooper    8 700    83 700    essence
# 3    62800  duster blue dci 115 4x2 prestige   19 800     2 000     diesel
# 4    63100    duster dci 110 4x4 black touch   16 000    67 000     diesel
#
#   emission fuel_usage  transmission door_nb technical_power actual_power  \
# 0      104        4.5      manuelle      5               4            82
# 1                       automatique      5               6           116
# 2      129        5.4      manuelle      4               6           120
# 3                          manuelle      5               6           115
# 4      123        4.7      manuelle      5               6           110
#
#   body_colour body_type   marque  modele date_fabrication
# 0         N/A   berline  citroen     ds3    novembre 2015
# 1  gris foncé       N/A     mini  cooper     octobre 2017
# 2  gris foncé   berline     mini  cooper        juin 2009
# 3       blanc       4x4    dacia  duster     janvier 2022
# 4         N/A       4x4    dacia  duster     février 2017

# %%
df_clean.fillna(0)
df_clean.head()
# Out:
#   location                           version     price   mileage fuel_type  \
# 0    27370          ds3 puretech 82 bvm chic   11 000    46 000    essence
# 1    68000   1.5 d 116 cooper pack chili bva   18 490    52 800     diesel
# 2    05230            mini 1.6i - 120 cooper    8 700    83 700    essence
# 3    62800  duster blue dci 115 4x2 prestige   19 800     2 000     diesel
# 4    63100    duster dci 110 4x4 black touch   16 000    67 000     diesel
#
#   emission fuel_usage  transmission door_nb technical_power actual_power  \
# 0      104        4.5      manuelle      5               4            82
# 1                       automatique      5               6           116
# 2      129        5.4      manuelle      4               6           120
# 3                          manuelle      5               6           115
# 4      123        4.7      manuelle      5               6           110
#
#   body_colour body_type   marque  modele date_fabrication
# 0         N/A   berline  citroen     ds3    novembre 2015
# 1  gris foncé       N/A     mini  cooper     octobre 2017
# 2  gris foncé   berline     mini  cooper        juin 2009
# 3       blanc       4x4    dacia  duster     janvier 2022
# 4         N/A       4x4    dacia  duster     février 2017
