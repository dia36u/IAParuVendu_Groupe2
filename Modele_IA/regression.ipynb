# %% [markdown]
# ### Import librairies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import metrics
from matplotlib import rcParams
rcParams['figure.figsize'] = 11.7,8.27

# %% [markdown]
# ### Import dataset

# %%
df = pd.read_json(r"data_harvest.json", lines=True)
df.head()
# Out:
#                                                  url  status  \
# 0  https://www.paruvendu.fr/a/voiture-occasion/ci...     200
# 1  https://www.paruvendu.fr/a/voiture-occasion/mi...     200
# 2  https://www.paruvendu.fr/a/voiture-occasion/mi...     200
# 3  https://www.paruvendu.fr/a/voiture-occasion/da...     200
# 4  https://www.paruvendu.fr/a/voiture-occasion/da...     200
#
#                    location                                   version  \
# 0   le thuit-signol (27370)          version ds3 puretech 82 bvm chic
# 1              68000 colmar   version 1.5 d 116 cooper pack chili bva
# 2           chorges (05230)            version mini 1.6i - 120 cooper
# 3            liévin (62800)  version duster blue dci 115 4x2 prestige
# 4  clermont-ferrand (63100)    version duster dci 110 4x4 black touch
#
#            price                                               year  \
# 0  prix 11 000 €  année novembre 2015 le comparateur d'assurance...
# 1  prix 18 490 €  année octobre 2017 le comparateur d'assurance ...
# 2   prix 8 700 €  année juin 2009 le comparateur d'assurance pou...
# 3  prix 19 800 €  année janvier 2022 le comparateur d'assurance ...
# 4  prix 16 000 €  année février 2017 le comparateur d'assurance ...
#
#                  mileage        fuel_type                   emission  \
# 0  kilométrage 46 000 km  energie essence  emissions de co2 104 g/km
# 1  kilométrage 52 800 km   energie diesel                        N/A
# 2  kilométrage 83 700 km  energie essence  emissions de co2 129 g/km
# 3   kilométrage 2 000 km   energie diesel                        N/A
# 4  kilométrage 67 000 km   energie diesel  emissions de co2 123 g/km
#
#                                fuel_usage              transmission  \
# 0  consommation mixte 4.5 litres / 100 km     transmission manuelle
# 1                                     N/A  transmission automatique
# 2  consommation mixte 5.4 litres / 100 km     transmission manuelle
# 3                                     N/A     transmission manuelle
# 4  consommation mixte 4.7 litres / 100 km     transmission manuelle
#
#                      door_nb         technical_power seat_nb actual_power  \
# 0  nombre de places 5 places  puissance fiscale 4 cv     N/A           82
# 1  nombre de places 5 places  puissance fiscale 6 cv     N/A          116
# 2  nombre de places 4 places  puissance fiscale 6 cv     N/A          120
# 3  nombre de places 5 places  puissance fiscale 6 cv     N/A          115
# 4  nombre de places 5 places  puissance fiscale 6 cv     N/A          110
#
#   body_colour body_type warranty control
# 0         N/A   berline      N/A     N/A
# 1  gris foncé       N/A      N/A     N/A
# 2  gris foncé   berline      N/A     N/A
# 3       blanc       4x4      N/A     N/A
# 4         N/A       4x4      N/A     N/A

# %%
df_clean=df.drop(['status','seat_nb','warranty','control'],axis=1)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8269 entries, 0 to 8268
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              8269 non-null   object
#  1   location         8269 non-null   object
#  2   version          8269 non-null   object
#  3   price            8269 non-null   object
#  4   year             8269 non-null   object
#  5   mileage          8269 non-null   object
#  6   fuel_type        8269 non-null   object
#  7   emission         8269 non-null   object
#  8   fuel_usage       8269 non-null   object
#  9   transmission     8269 non-null   object
#  10  door_nb          8269 non-null   object
#  11  technical_power  8269 non-null   object
#  12  actual_power     8269 non-null   object
#  13  body_colour      8269 non-null   object
#  14  body_type        8269 non-null   object
# dtypes: object(15)
# memory usage: 969.1+ KB

# %%
for i in range(0, len(df_clean)): 
    df_clean.iloc[i].fuel_type = df_clean.iloc[i].fuel_type[8:] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].emission = df_clean.iloc[i].emission[17:-5] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].transmission = df_clean.iloc[i].transmission[13:] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].fuel_usage = df_clean.iloc[i].fuel_usage[19:-16] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].url = df_clean.iloc[i].url[44:-22] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].version = df_clean.iloc[i].version[8:] 

for i in range(0, len(df_clean)): 
    df_clean.iloc[i].year = df_clean.iloc[i].year[6:] 

df_clean['door_nb'] = df_clean['door_nb'].str.replace(r'\D', '')
df_clean['location'] = df_clean['location'].str.replace(r'\D', '')
df_clean['price'] = df_clean['price'].str.replace(r'\D', '')
df_clean['mileage'] = df_clean['mileage'].str.replace(r'\D', '')
df_clean['technical_power'] = df_clean['technical_power'].str.replace(r'\D', '')

df_clean.head()
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_12988\1118373539.py:22: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_clean['door_nb'] = df_clean['door_nb'].str.replace(r'\D', '')
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_12988\1118373539.py:23: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_clean['location'] = df_clean['location'].str.replace(r'\D', '')
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_12988\1118373539.py:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_clean['price'] = df_clean['price'].str.replace(r'\D', '')
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_12988\1118373539.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_clean['mileage'] = df_clean['mileage'].str.replace(r'\D', '')
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_12988\1118373539.py:26: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_clean['technical_power'] = df_clean['technical_power'].str.replace(r'\D', '')
#             url location                           version  price  \
# 0   citroen/ds3    27370          ds3 puretech 82 bvm chic  11000
# 1   mini/cooper    68000   1.5 d 116 cooper pack chili bva  18490
# 2   mini/cooper    05230            mini 1.6i - 120 cooper   8700
# 3  dacia/duster    62800  duster blue dci 115 4x2 prestige  19800
# 4  dacia/duster    63100    duster dci 110 4x4 black touch  16000
#
#                                                 year mileage fuel_type  \
# 0  novembre 2015 le comparateur d'assurance pour ...   46000   essence
# 1  octobre 2017 le comparateur d'assurance pour c...   52800    diesel
# 2  juin 2009 le comparateur d'assurance pour cett...   83700   essence
# 3  janvier 2022 le comparateur d'assurance pour c...    2000    diesel
# 4  février 2017 le comparateur d'assurance pour c...   67000    diesel
#
#   emission fuel_usage transmission door_nb technical_power actual_power  \
# 0      104        4.5     manuelle       5               4           82
# 1                      automatique       5               6          116
# 2      129        5.4     manuelle       4               6          120
# 3                         manuelle       5               6          115
# 4      123        4.7     manuelle       5               6          110
#
#   body_colour body_type
# 0         N/A   berline
# 1  gris foncé       N/A
# 2  gris foncé   berline
# 3       blanc       4x4
# 4         N/A       4x4

# %%
df_marque=df_clean['url'].str.split('/',expand=True)
df_clean['marque']=df_marque[0]
df_clean['modele']=df_marque[1]
df_clean.drop(columns =["url"], inplace = True)

df_year=df_clean['year'].str.split(' le',expand=True)
df_clean['date_fabrication']=df_year[0]
df_clean.drop(columns =["year"], inplace = True)

df_clean.head()
# Out:
#   location                           version  price mileage fuel_type  \
# 0    27370          ds3 puretech 82 bvm chic  11000   46000   essence
# 1    68000   1.5 d 116 cooper pack chili bva  18490   52800    diesel
# 2    05230            mini 1.6i - 120 cooper   8700   83700   essence
# 3    62800  duster blue dci 115 4x2 prestige  19800    2000    diesel
# 4    63100    duster dci 110 4x4 black touch  16000   67000    diesel
#
#   emission fuel_usage transmission door_nb technical_power actual_power  \
# 0      104        4.5     manuelle       5               4           82
# 1                      automatique       5               6          116
# 2      129        5.4     manuelle       4               6          120
# 3                         manuelle       5               6          115
# 4      123        4.7     manuelle       5               6          110
#
#   body_colour body_type   marque  modele date_fabrication
# 0         N/A   berline  citroen     ds3    novembre 2015
# 1  gris foncé       N/A     mini  cooper     octobre 2017
# 2  gris foncé   berline     mini  cooper        juin 2009
# 3       blanc       4x4    dacia  duster     janvier 2022
# 4         N/A       4x4    dacia  duster     février 2017

# %%
df_clean['actual_power']=df_clean['actual_power'].replace('N/A', 0)
df_clean=df_clean.replace('N/A', np.nan)
df_clean=df_clean.replace('', 0)
df_clean.head()
# Out:
#   location                           version  price mileage fuel_type  \
# 0    27370          ds3 puretech 82 bvm chic  11000   46000   essence
# 1    68000   1.5 d 116 cooper pack chili bva  18490   52800    diesel
# 2    05230            mini 1.6i - 120 cooper   8700   83700   essence
# 3    62800  duster blue dci 115 4x2 prestige  19800    2000    diesel
# 4    63100    duster dci 110 4x4 black touch  16000   67000    diesel
#
#   emission fuel_usage transmission door_nb technical_power actual_power  \
# 0      104        4.5     manuelle       5               4           82
# 1        0          0  automatique       5               6          116
# 2      129        5.4     manuelle       4               6          120
# 3        0          0     manuelle       5               6          115
# 4      123        4.7     manuelle       5               6          110
#
#   body_colour body_type   marque  modele date_fabrication
# 0         NaN   berline  citroen     ds3    novembre 2015
# 1  gris foncé       NaN     mini  cooper     octobre 2017
# 2  gris foncé   berline     mini  cooper        juin 2009
# 3       blanc       4x4    dacia  duster     janvier 2022
# 4         NaN       4x4    dacia  duster     février 2017

# %%
df_clean=df_clean.rename(columns={"location": "code_postal", "price": "prix_vente", "mileage": "kilometrage",
 "fuel_type": "energie", "fuel_usage": "consommation ", "door_nb": "portes",
  "technical_power": "cv_fiscaux", "actual_power": "cv_reels", "body_colour": "couleur", "body_type": "carrosserie"})
df_clean.head()
# Out:
#   code_postal                           version prix_vente kilometrage  \
# 0       27370          ds3 puretech 82 bvm chic      11000       46000
# 1       68000   1.5 d 116 cooper pack chili bva      18490       52800
# 2       05230            mini 1.6i - 120 cooper       8700       83700
# 3       62800  duster blue dci 115 4x2 prestige      19800        2000
# 4       63100    duster dci 110 4x4 black touch      16000       67000
#
#    energie emission consommation  transmission portes cv_fiscaux cv_reels  \
# 0  essence      104           4.5     manuelle      5          4       82
# 1   diesel        0             0  automatique      5          6      116
# 2  essence      129           5.4     manuelle      4          6      120
# 3   diesel        0             0     manuelle      5          6      115
# 4   diesel      123           4.7     manuelle      5          6      110
#
#       couleur carrosserie   marque  modele date_fabrication
# 0         NaN     berline  citroen     ds3    novembre 2015
# 1  gris foncé         NaN     mini  cooper     octobre 2017
# 2  gris foncé     berline     mini  cooper        juin 2009
# 3       blanc         4x4    dacia  duster     janvier 2022
# 4         NaN         4x4    dacia  duster     février 2017

# %%
df_clean.dtypes
# Out:
# code_postal         object
# version             object
# prix_vente          object
# kilometrage         object
# energie             object
# emission            object
# consommation        object
# transmission        object
# portes              object
# cv_fiscaux          object
# cv_reels            object
# couleur             object
# carrosserie         object
# marque              object
# modele              object
# date_fabrication    object
# dtype: object

# %%
df_clean['emission']=df_clean['emission'].replace('nc', 0)
df_clean['emission']=df_clean['emission'].astype(float)
df_clean=df_clean.astype({'portes': 'int', 'cv_fiscaux': 'int', 'cv_reels': 'int'})

# %%
df_clean.to_json(r'data_harvest_clean.json',orient='records')

# %%
# df_clean = df_clean.reindex(columns=['version','marque','modele','date_fabrication','kilometrage','couleur','carrosserie'
# ,'code_postal','energie','emission','consommation','transmission','portes','cv_fiscaux','cv_reels','prix_vente'])
# df_clean.head()
