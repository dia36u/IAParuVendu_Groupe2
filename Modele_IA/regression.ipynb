# %% [markdown]
# ### Import librairies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import metrics
from matplotlib import rcParams
rcParams['figure.figsize'] = 11.7,8.27

# %% [markdown]
# ### Import dataset

# %%
#df = pd.read_json(r"C:\Users\diaba\Documents\SimplonIAMicrosoft_21-23\IAParuVendu_Groupe2\Modele_IA\data_harvest.json", lines=True)
df = pd.read_json(r"data_harvest.json", lines=True)

df.head()
# Out:
#                                                  url  status  \
# 0  https://www.paruvendu.fr/a/voiture-occasion/ci...     200
# 1  https://www.paruvendu.fr/a/voiture-occasion/mi...     200
# 2  https://www.paruvendu.fr/a/voiture-occasion/mi...     200
# 3  https://www.paruvendu.fr/a/voiture-occasion/da...     200
# 4  https://www.paruvendu.fr/a/voiture-occasion/da...     200
#
#                    location                                   version  \
# 0   le thuit-signol (27370)          version ds3 puretech 82 bvm chic
# 1              68000 colmar   version 1.5 d 116 cooper pack chili bva
# 2           chorges (05230)            version mini 1.6i - 120 cooper
# 3            liévin (62800)  version duster blue dci 115 4x2 prestige
# 4  clermont-ferrand (63100)    version duster dci 110 4x4 black touch
#
#            price                                               year  \
# 0  prix 11 000 €  année novembre 2015 le comparateur d'assurance...
# ...

# %%
df.describe()
df_clean=df.drop(['status','seat_nb','warranty','control'],axis=1)
df_clean.head()
df['body_colour'].value_counts()
# Out:
# blanc                 1393
# noir                  1235
# N/A                    730
# gris clair             671
# gris                   452
#                       ...
# m misanoblau             1
# galvanic gold            1
# peinture bleu iron       1
# beige metal              1
# omaha orange             1
# Name: body_colour, Length: 718, dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8269 entries, 0 to 8268
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              8269 non-null   object
#  1   location         8269 non-null   object
#  2   version          8269 non-null   object
#  3   price            8269 non-null   object
#  4   year             8269 non-null   object
#  5   mileage          8269 non-null   object
#  6   fuel_type        8269 non-null   object
#  7   emission         8269 non-null   object
#  8   fuel_usage       8269 non-null   object
#  9   transmission     8269 non-null   object
#  10  door_nb          8269 non-null   object
#  11  technical_power  8269 non-null   object
#  12  actual_power     8269 non-null   object
#  13  body_colour      8269 non-null   object
#  14  body_type        8269 non-null   object
# dtypes: object(15)
# memory usage: 969.1+ KB

# %%
#df_clean["transmission"].astype('category')

#df_clean["body_colour"].astype('category')

df_clean["body_type"].astype('category')
# Out:
# 0       berline
# 1           N/A
# 2       berline
# 3           4x4
# 4           4x4
#          ...
# 8264    berline
# 8265    berline
# 8266    berline
# 8267    berline
# 8268    berline
# Name: body_type, Length: 8269, dtype: category
# Categories (9, object): ['4x4', 'N/A', 'berline', 'break', ..., 'coupé', 'monospace', 'pick-up', 'véhicule']

# %%
# for i in range(0, len(df)): 
#     df_clean.iloc[i].price = df.iloc[i].price[4:-1] 

# for i in range(0, len(df)): 
#     df_clean.iloc[i].mileage = df.iloc[i].mileage[11:-2] 

# for i in range(0, len(df)): 
#     df_clean.iloc[i].fuel_type = df.iloc[i].fuel_type[8:] 

# for i in range(0, len(df)): 
#     df_clean.iloc[i].emission = df.iloc[i].emission[16:-5] 

# for i in range(0, len(df)): 
#     df_clean.iloc[i].door_nb = df.iloc[i].door_nb[16:-6] 

# for i in range(0, len(df)): 
#     df_clean.iloc[i].technical_power = df.iloc[i].technical_power[17:-2] 


df_clean.head()
# Out:
#                                                  url  \
# 0  https://www.paruvendu.fr/a/voiture-occasion/ci...
# 1  https://www.paruvendu.fr/a/voiture-occasion/mi...
# 2  https://www.paruvendu.fr/a/voiture-occasion/mi...
# 3  https://www.paruvendu.fr/a/voiture-occasion/da...
# 4  https://www.paruvendu.fr/a/voiture-occasion/da...
#
#                    location                                   version  \
# 0   le thuit-signol (27370)          version ds3 puretech 82 bvm chic
# 1              68000 colmar   version 1.5 d 116 cooper pack chili bva
# 2           chorges (05230)            version mini 1.6i - 120 cooper
# 3            liévin (62800)  version duster blue dci 115 4x2 prestige
# 4  clermont-ferrand (63100)    version duster dci 110 4x4 black touch
#
#            price                                               year  \
# 0  prix 11 000 €  année novembre 2015 le comparateur d'assurance...
# 1  prix 18 490 €  année octobre 2017 le comparateur d'assurance ...
# ...

# %%
#df_clean['location'].replace('colmar', '')

#df_clean['location'] = df_clean['location'].map(lambda x: x.lstrip('()').rstrip('abcdefghijklmnopkrstuvwxyz'))

#df_clean['location'] = df_clean['location'].str.replace('abcdefghijklmnopkrstuvwxyz','')

df_clean = df_clean.replace('colmar','', regex=True)



df_clean.head()
# Out:
#                                                  url  \
# 0  https://www.paruvendu.fr/a/voiture-occasion/ci...
# 1  https://www.paruvendu.fr/a/voiture-occasion/mi...
# 2  https://www.paruvendu.fr/a/voiture-occasion/mi...
# 3  https://www.paruvendu.fr/a/voiture-occasion/da...
# 4  https://www.paruvendu.fr/a/voiture-occasion/da...
#
#                    location                                   version  \
# 0   le thuit-signol (27370)          version ds3 puretech 82 bvm chic
# 1                    68000    version 1.5 d 116 cooper pack chili bva
# 2           chorges (05230)            version mini 1.6i - 120 cooper
# 3            liévin (62800)  version duster blue dci 115 4x2 prestige
# 4  clermont-ferrand (63100)    version duster dci 110 4x4 black touch
#
#            price                                               year  \
# 0  prix 11 000 €  année novembre 2015 le comparateur d'assurance...
# 1  prix 18 490 €  année octobre 2017 le comparateur d'assurance ...
# ...
